# %%
import seaborn as sns
sns.set()
sns.set(style="darkgrid")


import numpy as np
import pandas as pd

# importing matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Load dataset

# read the dataset
data_BM = pd.read_csv('titanic.csv')
# drop the null values
#data_BM = data_BM.dropna(how="any")
# multiply Item_Visibility by 100 to increase size
#data_BM["Visibility_Scaled"] = data_BM["Item_Visibility"] * 100
# view the top results
data_BM.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [raw]
# #line chart with facet grid
# #g = sns.FacetGrid(data_BM, col="survived",  row="boat")
# #g.map(sns.lineplot, "survived", "boat")
# #sns.lineplot(x="parch", y="sibsp",data=data_BM);
# plt.lineplot(x="parch", y="sibsp",data=data_BM[:50]);

# %%
sns.lineplot(x="age", y="survived",data=data_BM[:10]);

# %%
sns.countplot(x="sex",data=data_BM,hue='survived');

# %%
sns.barplot(x="survived", y="age",data=data_BM, ci=None);

# %%
data_BM = pd.read_csv('titanic.csv')

# %%
#pair plot and hist plot  --Pair plot

#penguins = sns.load_dataset("data_BM")

sns.pairplot(data_BM,hue='survived',size=3)

# %%
g = sns.FacetGrid(data_BM[:10], col="age",  row="survived")
g.map(sns.scatterplot, "age", "survived")

# %%
g = sns.FacetGrid(data_BM[:5], col="age",  row="survived")
g.map(sns.pairplot, "age", "survived")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 2
#       1 g = sns.FacetGrid(data_BM[:5], col="age",  row="survived")
# ----> 2 g.map(sns.pairplot, "age", "survived")
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:758, in FacetGrid.map(self, func, *args, **kwargs)
#     755         plot_args = [v.values for v in plot_args]
#     757     # Draw the plot
# --> 758     self._facet_plot(func, ax, plot_args, kwargs)
#     760 # Finalize the annotations and layout
#     761 self._finalize_grid(args[:2])
#
# File ~\anaconda3\Lib\site-packages\seaborn\axisgrid.py:854, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     852     plot_args = []
#     853     plot_kwargs["ax"] = ax
# --> 854 func(*plot_args, **plot_kwargs)
#     856 # Sort out the supporting information
#     857 self._update_legend_data(ax)
#
# ...
